# %% [markdown]
# <a href="https://colab.research.google.com/github/Karina0162003/MLP_Programs/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = {'1':['me','me1','me2'],'2':['me','me1','me2']}
df
# Out:
# {'1': ['me', 'me1', 'me2'], '2': ['me', 'me1', 'me2']}

# %%
df1 = pd.DataFrame(df)
df1
# Out:
#      1    2
# 0   me   me
# 1  me1  me1
# 2  me2  me2

# %%
df1.rename(columns={'1':'me1'},inplace=True)
df1
# Out:
#    me1    2
# 0   me   me
# 1  me1  me1
# 2  me2  me2

# %%
df1.info
# Out:
# <bound method DataFrame.info of    me1    2
# 0   me   me
# 1  me1  me1
# 2  me2  me2>

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of    me1    2
# 0   me   me
# 1  me1  me1
# 2  me2  me2>

# %%
df1.columns
# Out:
# Index(['me1', '2'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1['me3']=['me','me1','me2']
df1
# Out:
#    me1    2  me3
# 0   me   me   me
# 1  me1  me1  me1
# 2  me2  me2  me2

# %%
df1.drop(columns=['2'],inplace=True)

# %%
df1
# Out:
#    me1  me3
# 0   me   me
# 1  me1  me1
# 2  me2  me2

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
df2=pd.read_csv('/content/data.csv')
df2.head(3)
# Out:
#    Age  Height  Weight Gender      Education   Income Region
# 0   35   160.0    70.0   Male       Graduate  50000.0  North
# 1   30   155.0    65.0  Femal   Postgraduate  40000.0  South
# 2   40   162.0    65.0   Male  Undergraduate  35000.0   East

# %%
df2.shape
# Out:
# (41, 7)

# %%
df2.size
# Out:
# 287

# %%
df2.tail(3)
# Out:
#     Age  Height  Weight Gender      Education   Income Region
# 38   35     NaN    70.0   Male       Graduate  50000.0  North
# 39   30   155.0     NaN  Femal   Postgraduate  40000.0  South
# 40   40   162.0    65.0    NaN  Undergraduate  35000.0   East

# %%
df2.iloc[:2]
# Out:
#    Age  Height  Weight Gender     Education   Income Region
# 0   35   160.0    70.0   Male      Graduate  50000.0  North
# 1   30   155.0    65.0  Femal  Postgraduate  40000.0  South

# %%
df2.loc['0':'Age']
# Out:
#     Age  Height  Weight Gender                      Education    Income  \
# 0    35   160.0    70.0   Male                       Graduate   50000.0
# 1    30   155.0    65.0  Femal                   Postgraduate   40000.0
# 2    40   162.0    65.0   Male                  Undergraduate   35000.0
# 3    45   160.0    62.0   Male                    High School   70000.0
# 4    25   145.0    45.0  Femal  Vocational/Technical Training   25000.0
# 5    30   150.0    52.0  Femal             Associate's Degree  450000.0
# 6    42   152.0    58.0   Male        Some College, No Degree   65000.0
# 7    35   155.0    60.0   Male            High School Dropout   20000.0
# 8    30   148.0    48.0  Femal            Professional Degree   65000.0
# 9    28   146.0    54.0  Femal            Certificate Program   15000.0
# 10   35   160.0    70.0   Male                       Graduate   50000.0
# 11   30   155.0    65.0  Femal                   Postgraduate   40000.0
# ...

# %%
df2.isna().sum()
# Out:
# Age          0
# Height       0
# Weight       0
# Gender       0
# Education    0
# Income       0
# Region       0
# dtype: int64

# %%
df2.notnull().sum()
# Out:
# Age          41
# Height       41
# Weight       41
# Gender       41
# Education    41
# Income       41
# Region       41
# dtype: int64

# %%
df2.fillna('nan',inplace=True)

# %%
df2[['Age','Height']].tail(3)
# Out:
#     Age Height
# 38   35    nan
# 39   30  155.0
# 40   40  162.0

# %%
df2[['Age']].values
# Out:
# array([[35],
#        [30],
#        [40],
#        [45],
#        [25],
#        [30],
#        [42],
#        [35],
#        [30],
#        [28],
#        [35],
#        [30],
#        [40],
#        [45],
#        [25],
#        [30],
#        [42],
#        [35],
#        [30],
#        [28],
#        [25],
#        [30],
#        [42],
#        [35],
#        [30],
#        [28],
#        [35],
#        [30],
#        [40],
#        [35],
#        [30],
#        [28],
#        [25],
#        [30],
#        [42],
#        [35],
#        [30],
#        [28],
#        [35],
#        [30],
#        [40]])

# %%
df2[['Age']].value_counts()
# Out:
# Age
# 30     13
# 35      9
# 28      5
# 25      4
# 40      4
# 42      4
# 45      2
# Name: count, dtype: int64

# %%
df3=pd.read_csv('/content/Movie-Data.csv')
df3.tail(3)
# Out:
#      Rank                   Title                  Genre  \
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 997                 98     6.2  70699               58.01       50.0
# ...

# %%
b=df2.groupby('Age')['Income'].sum()
b
# Out:
# Age
# 25     100000.0
# 28      75000.0
# 30    2285000.0
# 35     300000.0
# 40     140000.0
# 42    1930000.0
# 45     140000.0
# Name: Income, dtype: float64

# %%
df2['Income'].replace({'nan':900000.0},inplace=True)

# %%
df2
# Out:
#     Age Height Weight Gender                      Education    Income  \
# 0    35  160.0   70.0   Male                       Graduate   50000.0
# 1    30  155.0   65.0  Femal                   Postgraduate   40000.0
# 2    40  162.0   65.0   Male                  Undergraduate   35000.0
# 3    45  160.0   62.0   Male                    High School   70000.0
# 4    25  145.0   45.0  Femal  Vocational/Technical Training   25000.0
# 5    30  150.0   52.0  Femal             Associate's Degree  450000.0
# 6    42  152.0   58.0   Male        Some College, No Degree   65000.0
# 7    35  155.0   60.0   Male            High School Dropout   20000.0
# 8    30  148.0   48.0  Femal            Professional Degree   65000.0
# 9    28  146.0   54.0  Femal            Certificate Program   15000.0
# 10   35  160.0   70.0   Male                       Graduate   50000.0
# 11   30  155.0   65.0  Femal                   Postgraduate   40000.0
# ...

# %%
df3.tail(2)
# Out:
#      Rank         Title                  Genre  \
# 998   999  Search Party       Adventure,Comedy
# 999  1000    Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 998                 93     5.6   4881                 NaN       22.0
# 999                 87     5.3  12435               19.64       11.0

# %%
df3['Votes'].mean()
# Out:
# 169808.255

# %%
df3['Votes'].sum()
# Out:
# 169808255

# %%
df3['Votes'].idxmin()
# Out:
# 478

# %%
df3['Votes'].idxmax()
# Out:
# 54

# %%
r=df2.sort_values(by=['Age','Weight'],ascending=[True,False])
r
# Out:
#     Age Height Weight Gender                      Education    Income  \
# 4    25  145.0   45.0  Femal  Vocational/Technical Training   25000.0
# 14   25  145.0   45.0  Femal  Vocational/Technical Training   25000.0
# 20   25  145.0   45.0    nan  Vocational/Technical Training   25000.0
# 32   25  145.0   45.0    nan  Vocational/Technical Training   25000.0
# 9    28  146.0   54.0  Femal            Certificate Program   15000.0
# 19   28    nan   54.0    nan            Certificate Program   15000.0
# 25   28  146.0   54.0  Femal            Certificate Program   15000.0
# 31   28    nan   54.0    nan            Certificate Program   15000.0
# 37   28  146.0   54.0  Femal            Certificate Program   15000.0
# 27   30  155.0    nan  Femal                   Postgraduate   40000.0
# 39   30  155.0    nan  Femal                   Postgraduate   40000.0
# 1    30  155.0   65.0  Femal                   Postgraduate   40000.0
# ...

# %%
z = df2[(df2['Age']>28) & (df2['Income']>90222)]
z
# Out:
#     Age Height Weight Gender                Education    Income     Region
# 5    30  150.0   52.0  Femal       Associate's Degree  450000.0    Midwest
# 15   30  150.0   52.0  Femal       Associate's Degree  450000.0    Midwest
# 21   30  150.0   52.0  Femal       Associate's Degree  450000.0        nan
# 22   42  152.0   58.0   Male  Some College, No Degree  900000.0  Northeast
# 33   30  150.0   52.0  Femal       Associate's Degree  450000.0        nan
# 34   42  152.0   58.0   Male  Some College, No Degree  900000.0  Northeast

# %%
df2['me']= df2['Income'] + df2['Income']
df2
# Out:
#     Age Height Weight Gender                      Education    Income  \
# 0    35  160.0   70.0   Male                       Graduate   50000.0
# 1    30  155.0   65.0  Femal                   Postgraduate   40000.0
# 2    40  162.0   65.0   Male                  Undergraduate   35000.0
# 3    45  160.0   62.0   Male                    High School   70000.0
# 4    25  145.0   45.0  Femal  Vocational/Technical Training   25000.0
# 5    30  150.0   52.0  Femal             Associate's Degree  450000.0
# 6    42  152.0   58.0   Male        Some College, No Degree   65000.0
# 7    35  155.0   60.0   Male            High School Dropout   20000.0
# 8    30  148.0   48.0  Femal            Professional Degree   65000.0
# 9    28  146.0   54.0  Femal            Certificate Program   15000.0
# 10   35  160.0   70.0   Male                       Graduate   50000.0
# 11   30  155.0   65.0  Femal                   Postgraduate   40000.0
# ...

# %%
for col in df2['Region']:
  print(col)
# Out:
# North
# South
# East
# West
# Central
# Midwest
# Northeast
# Southeast
# Southwest
# Northwest
# North
# South
# East
# West
# Central
# Midwest
# Northeast
# Southeast
# Southwest
# Northwest
# Central
# nan
# Northeast
# Southeast
# Southwest
# Northwest
# North
# South
# East
# Southeast
# Southwest
# Northwest
# Central
# nan
# Northeast
# Southeast
# Southwest
# Northwest
# North
# South
# East

# %%
df2.tail(2)
# Out:
#     Age Height Weight Gender      Education   Income Region       me
# 39   30  155.0    nan  Femal   Postgraduate  40000.0  South  80000.0
# 40   40  162.0   65.0    nan  Undergraduate  35000.0   East  70000.0

# %%
i=df2[df2['Income'].isin([40000.0])]
i
# Out:
#     Age Height Weight Gender     Education   Income Region       me
# 1    30  155.0   65.0  Femal  Postgraduate  40000.0  South  80000.0
# 11   30  155.0   65.0  Femal  Postgraduate  40000.0  South  80000.0
# 27   30  155.0    nan  Femal  Postgraduate  40000.0  South  80000.0
# 39   30  155.0    nan  Femal  Postgraduate  40000.0  South  80000.0

# %%
df2.iloc[2][3]
# Out:
# 'Male'

# %%
df2.loc[4][1]
# Out:
# 145.0
