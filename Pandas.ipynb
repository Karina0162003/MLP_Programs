# %% [markdown]
# <a href="https://colab.research.google.com/github/Karina0162003/MLP_Programs/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/pokemon_data.csv")
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head() #show the starting 5 rows 0 to 4
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail() #ending 5 row are showing.
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df[['Type 1','Type 2']]
# Out:
#       Type 1  Type 2
# 0      Grass  Poison
# 1      Grass  Poison
# 2      Grass  Poison
# 3      Grass  Poison
# 4       Fire     NaN
# ..       ...     ...
# 795     Rock   Fairy
# 796     Rock   Fairy
# 797  Psychic   Ghost
# 798  Psychic    Dark
# 799     Fire   Water
#
# [800 rows x 2 columns]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df["Total"] = df["HP"]+df["Attack"]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False     94
# ...

# %%
df1 = df.loc[df["HP"].idxmin()]
df1
# Out:
# #                  292
# Name          Shedinja
# Type 1             Bug
# Type 2           Ghost
# HP                   1
# Attack              90
# Defense             45
# Sp. Atk             30
# Sp. Def             30
# Speed               40
# Generation           3
# Legendary        False
# Total               91
# Name: 316, dtype: object

# %%
df2 = df.loc[df["HP"].idxmax()]
df2
# Out:
# #                 242
# Name          Blissey
# Type 1         Normal
# Type 2            NaN
# HP                255
# Attack             10
# Defense            10
# Sp. Atk            75
# Sp. Def           135
# Speed              55
# Generation          2
# Legendary       False
# Total             265
# Name: 261, dtype: object

# %%
df.iloc[10:15]
# Out:
#      #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 10   8                Wartortle  Water    NaN  59      63       80       65
# 11   9                Blastoise  Water    NaN  79      83      100       85
# 12   9  BlastoiseMega Blastoise  Water    NaN  79     103      120      135
# 13  10                 Caterpie    Bug    NaN  45      30       35       20
# 14  11                  Metapod    Bug    NaN  50      20       55       25
#
#     Sp. Def  Speed  Generation  Legendary  Total
# 10       80     58           1      False    122
# 11      105     78           1      False    162
# 12      115     78           1      False    182
# 13       20     45           1      False     75
# 14       25     30           1      False     70

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total'],
#       dtype='object')

# %%
df['Type 1'].sort_values()
# Out:
# 600      Bug
# 136      Bug
# 457      Bug
# 132      Bug
# 656      Bug
#        ...
# 172    Water
# 610    Water
# 145    Water
# 574    Water
# 184    Water
# Name: Type 1, Length: 800, dtype: object

# %%
df["HP"].mean()
# Out:
# 69.25875

# %%
# second csv file

# %%
df6=pd.read_csv("/content/employees.csv")
print(df6)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df6.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df7 = df6.loc[df6["Salary"].idxmin()]
df7
# Out:
# First Name             Michael
# Gender                    Male
# Start Date           7/30/1993
# Last Login Time        5:35 PM
# Salary                   35013
# Bonus %                 14.879
# Senior Management        False
# Team                   Product
# Name: 576, dtype: object

# %%
df8 = df6.loc[df6["Salary"].idxmax()]
df8
# Out:
# First Name           Katherine
# Gender                  Female
# Start Date           8/13/1996
# Last Login Time       12:21 AM
# Salary                  149908
# Bonus %                 18.912
# Senior Management        False
# Team                   Finance
# Name: 644, dtype: object

# %%
df6["Salary"].mean()
# Out:
# 90662.181

# %%
df6["Gross"] = df6["Salary"]+df6["Bonus %"]

# %%
df6
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team       Gross
# 0                True             Marketing   97314.945
# ...

# %%
df6.notnull()
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0          True    True        True             True    True     True
# 1          True    True        True             True    True     True
# 2          True    True        True             True    True     True
# 3          True    True        True             True    True     True
# 4          True    True        True             True    True     True
# ..          ...     ...         ...              ...     ...      ...
# 995        True   False        True             True    True     True
# 996        True    True        True             True    True     True
# 997        True    True        True             True    True     True
# 998        True    True        True             True    True     True
# 999        True    True        True             True    True     True
#
#      Senior Management   Team  Gross
# 0                 True   True   True
# 1                 True  False   True
# ...

# %%
df6['Salary'].isnull().sum()
# Out:
# 0

# %%
df6.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team', 'Gross'],
#       dtype='object')

# %%
profit = (df6["Salary"]*df6["Bonus %"]/100)

# %%
df6["Gross"]=df6["Salary"]+profit

# %%
df6
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team         Gross
# 0                True             Marketing  104066.04060
# ...

# %%
df6[df6["Salary"]>99000]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# ..         ...     ...         ...             ...     ...      ...
# 990      Robin  Female   7/24/1987         1:35 PM  100765   10.982
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team         Gross
# 2               False               Finance  146075.36220
# ...

# %%
df6["Gender"].replace({"NaN": "No gender"}, inplace=True)

# %%
df6
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team         Gross
# 0                True             Marketing  104066.04060
# ...

# %%
# Replace missing values in the "Gender" column with "Unknown"
df6["Gender"].fillna("Unknown", inplace=True)

# %%
df6
# Out:
#     First Name   Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas     Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas     Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria   Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry     Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry     Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...      ...         ...             ...     ...      ...
# 995      Henry  Unknown  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip     Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell     Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry     Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert     Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team         Gross
# 0                True             Marketing  104066.04060
# ...

# %%
# Replace missing values in the "Gender" column with "Unknown"
# df6["Gender"].replace(to_replace=None, value="Unknown", inplace=True)

# %%
missing_data = df6[df6.isnull().any(axis=1)]
missing_data
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 7          NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 10      Louise  Female  8/12/1980         9:01 AM   63241   15.132
# 23         NaN    Male  6/14/2012         4:19 PM  125792    5.042
# 25         NaN    Male  10/8/2012         1:12 AM   37076   18.576
# ..         ...     ...        ...             ...     ...      ...
# 912        Joe    Male  12/8/1998        10:28 AM  126120    1.020
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team         Gross
# 1                True              NaN   64515.60610
# 7                 NaN          Finance   51230.17788
# ...

# %%
grouped_data = df6.groupby("Team").mean()
# Out:
# <ipython-input-68-59fe5bee78c1>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = df6.groupby("Team").mean()

# %%
df6["Start Date"]=pd.to_datetime(df6["Start Date"])

# %%
df6["LastLogin Time"]=pd.to_datetime(df6["LastLogin Time"])

# %%
selected_columns = df6[["First Name", "Gender", "Salary"]]
selected_columns
# Out:
#     First Name   Gender  Salary
# 0      Douglas     Male   97308
# 1       Thomas     Male   61933
# 2        Maria   Female  130590
# 3        Jerry     Male  138705
# 4        Larry     Male  101004
# ..         ...      ...     ...
# 995      Henry  Unknown  132483
# 996    Phillip     Male   42392
# 997    Russell     Male   96914
# 998      Larry     Male   60500
# 999     Albert     Male  129949
#
# [1000 rows x 3 columns]

# %%
gender_salary = df6.groupby("Gender")["Salary"].mean()
gender_salary
# Out:
# Gender
# Female     90023.923434
# Male       91180.669811
# Unknown    91043.213793
# Name: Salary, dtype: float64

# %%
sorted_data = df6.sort_values(by=["Gender", "Salary"], ascending=[True, False])
sorted_data
# Out:
#     First Name   Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine   Female 1996-08-13        12:21 AM  149908   18.912
# 429       Rose   Female 2015-05-28         8:40 AM  149903    5.630
# 828    Cynthia   Female 2006-07-12         8:55 AM  149684    7.864
# 186        NaN   Female 2005-02-23         9:50 PM  149654    1.825
# 160      Kathy   Female 2000-03-18         7:26 PM  149563   16.991
# ..         ...      ...        ...             ...     ...      ...
# 168      Peter  Unknown 1987-09-03         5:59 PM   38989    7.017
# 303       Joan  Unknown 1980-07-25        12:22 PM   38712    3.657
# 230     George  Unknown 1988-02-24        11:29 AM   38375    8.999
# 989     Justin  Unknown 1991-02-10         4:58 PM   38344    3.794
# 417      Sarah  Unknown 1981-08-31         2:51 PM   37748    9.047
#
#     Senior Management             Team         Gross
# 644             False          Finance  178258.60096
# ...

# %%
filter = df6[(df6["Salary"]>65000) & (df6["Senior Management"]==True)]

# %%
filter
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry    Male 1998-01-24         4:47 PM  101004    1.389
# 6         Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 8       Angela  Female 2005-11-22         6:29 AM   95570   18.523
# ..         ...     ...        ...             ...     ...      ...
# 990      Robin  Female 1987-07-24         1:35 PM  100765   10.982
# 991       Rose  Female 2002-08-25         5:12 AM  134505   11.051
# 992    Anthony    Male 2011-10-16         8:35 AM  112769   11.625
# 994     George    Male 2013-06-21         5:47 PM   98874    4.479
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management             Team         Gross
# 0                True        Marketing  104066.04060
# 3                True          Finance  151660.04700
# ...

# %%
df6.drop_duplicates(inplace=True)

# %%
df6.dropna(inplace=True)

# %%
df6.to_csv("output.csv", index=False)
